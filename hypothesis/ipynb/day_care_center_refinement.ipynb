# %%
import pandas as pd  # 데이터를 다루기 위한 pandas 라이브러리 불러오기
import numpy as np  # 수치 연산을 위한 numpy 라이브러리 불러오기
import matplotlib.pyplot as plt  # 시각화를 위한 matplotlib 불러오기
import seaborn as sns  # 고급 시각화를 위한 seaborn 불러오기
import warnings  # 경고 메시지 처리를 위한 warnings 라이브러리 불러오기

# 경고 메시지를 무시하도록 설정
warnings.filterwarnings('ignore')
# 그래프를 노트북 안에 표시하기 위한 설정
# %matplotlib inline

# 그래프에 사용할 폰트를 'Malgun Gothic'으로 설정
plt.rc("font", family="Malgun Gothic")
sns.set(font="Malgun Gothic", rc={"axes.unicode_minus": False}, style='white')

# %%
# CSV 파일을 읽어서 DataFrame으로 저장
day_care_center_df = pd.read_csv('/content/sample_data/Apartment_Price/day_care_center.csv')

# %%
# 'day_care_name' 열의 모든 공백을 제거합니다
day_care_center_df['day_care_name'] = day_care_center_df['day_care_name'].str.replace(' ', '', regex=True)

# 'reference_date' 열을 삭제합니다
day_care_center_df = day_care_center_df.drop(columns=['reference_date'])

# %% [markdown]
# * city = 도시 이름
# * gu = 구(강동구, 송파구 등)
# * dong = 동(잠실동, 역삼동 등)
# * park_name = 공원 이름
# * park_type = 공원 유형(근린공원, 어린이공원 등)
# * park_area = 공원 면적(단위: 제곱미터)
# * park_exercise_facility = 공원 내 운동시설(풋살장, 체력단련장, 배드민턴장 등)
# * park_entertainment_facility = 공원 내 여가시설
# * park_cultural_facility = 공원 내 문화시설
# * park_facility_other = 공원 내 기타 시설
# * park_open_year = 공원 개장 연도
# * reference_data = 관련 일자(수정일자?)

# %%
# 수정된 DataFrame을 새로운 CSV 파일로 저장합니다 (선택 사항)
day_care_center_df.to_csv('/content/sample_data/Apartment_Price/day_care_center_cleaned.csv', index=False)

# %%
# 데이터의 처음 5개 행을 출력하여 확인합니다
print(day_care_center_df.head())
# DataFrame의 정보(열 수, 결측치 등)를 출력하여 확인합니다
print(day_care_center_df.info())
# Out:
#     city    gu day_care_name day_care_type  day_care_baby_num  teacher_num  \
# 0  서울특별시  서대문구        가람어린이집           국공립                 70         11.0
# 1  서울특별시  서대문구      가좌제일어린이집           국공립                 88         22.0
# 2  서울특별시  서대문구       경찰청어린이집            직장                 90         23.0
# 3  서울특별시  서대문구      고운햇살어린이집            가정                 18          5.0
# 4  서울특별시  서대문구        고은어린이집           국공립                 93         20.0
#
#    nursing_room_num  playground_num  CCTV_num is_commuting_vehicle
# 0               5.0             1.0       7.0                    N
# 1               5.0             2.0      10.0                    N
# 2               6.0             1.0      32.0                    N
# 3               3.0             0.0       4.0                    N
# 4               7.0             2.0      10.0                    N
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7551 entries, 0 to 7550
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   city                  7551 non-null   object
#  1   gu                    7551 non-null   object
#  2   day_care_name         7551 non-null   object
#  3   day_care_type         7551 non-null   object
#  4   day_care_baby_num     7551 non-null   int64
#  5   teacher_num           7326 non-null   float64
#  6   nursing_room_num      4352 non-null   float64
#  7   playground_num        3626 non-null   float64
#  8   CCTV_num              5280 non-null   float64
#  9   is_commuting_vehicle  7055 non-null   object
# dtypes: float64(4), int64(1), object(5)
# memory usage: 590.0+ KB
# None

# %%
# 서울특별시와 부산광역시 데이터를 분리합니다
seoul_data = day_care_center_df[day_care_center_df['city'] == '서울특별시']
busan_data = day_care_center_df[day_care_center_df['city'] == '부산광역시']

# %%
# 서울 데이터의 각 열에 대한 결측치 총 개수 및 비율을 계산합니다
missing_values_seoul = seoul_data.isnull().sum()
total_data_seoul = len(seoul_data)
missing_percent_seoul = (missing_values_seoul / total_data_seoul) * 100

# 부산 데이터의 각 열에 대한 결측치 총 개수 및 비율을 계산합니다
missing_values_busan = busan_data.isnull().sum()
total_data_busan = len(busan_data)
missing_percent_busan = (missing_values_busan / total_data_busan) * 100

# %%
# 서울 데이터의 결측치 개수와 비율을 출력합니다
print(missing_values_seoul, '\n' * 3, missing_percent_seoul)

# 부산 데이터의 결측치 개수와 비율을 출력합니다
print(missing_values_busan, '\n' * 3, missing_percent_busan)
# Out:
# city                       0
# gu                         0
# day_care_name              0
# day_care_type              0
# day_care_baby_num          0
# teacher_num              225
# nursing_room_num        2699
# playground_num          3163
# CCTV_num                1811
# is_commuting_vehicle     495
# dtype: int64
#
#
#  city                     0.000000
# gu                       0.000000
# day_care_name            0.000000
# day_care_type            0.000000
# day_care_baby_num        0.000000
# teacher_num              3.978076
# nursing_room_num        47.719236
# playground_num          55.922914
# CCTV_num                32.019095
# is_commuting_vehicle     8.751768
# dtype: float64
# city                      0
# gu                        0
# day_care_name             0
# day_care_type             0
# day_care_baby_num         0
# teacher_num               0
# nursing_room_num        500
# playground_num          762
# CCTV_num                460
# is_commuting_vehicle      1
# dtype: int64
#
#
#  city                     0.000000
# gu                       0.000000
# day_care_name            0.000000
# day_care_type            0.000000
# day_care_baby_num        0.000000
# teacher_num              0.000000
# nursing_room_num        26.385224
# playground_num          40.211082
# CCTV_num                24.274406
# is_commuting_vehicle     0.052770
# dtype: float64

# %%
# 서울 데이터에서 불필요한 열이 제대로 삭제되었는지 확인합니다
print(seoul_data.head(50))

# 부산 데이터에서 불필요한 열이 제대로 삭제되었는지 확인합니다
print(busan_data.head(50))
# Out:
#      city    gu day_care_name day_care_type  day_care_baby_num  teacher_num  \
# 0   서울특별시  서대문구        가람어린이집           국공립                 70         11.0
# 1   서울특별시  서대문구      가좌제일어린이집           국공립                 88         22.0
# 2   서울특별시  서대문구       경찰청어린이집            직장                 90         23.0
# 3   서울특별시  서대문구      고운햇살어린이집            가정                 18          5.0
# 4   서울특별시  서대문구        고은어린이집           국공립                 93         20.0
# 5   서울특별시  서대문구      그루터기어린이집            가정                 19          3.0
# 6   서울특별시  서대문구        금화어린이집           국공립                 86         18.0
# 7   서울특별시  서대문구       꼬꼬마어린이집            가정                 20          7.0
# 8   서울특별시  서대문구      꼬마박사어린이집            가정                 19          6.0
# 9   서울특별시  서대문구       꼬마숲어린이집            가정                 20          7.0
# 10  서울특별시  서대문구       꾸러기어린이집            가정                 20          7.0
# 11  서울특별시  서대문구      꿈빛나무어린이집           국공립                 66         12.0
# 12  서울특별시  서대문구       꿈사랑어린이집            민간                 39          9.0
# 13  서울특별시  서대문구       꿈하은어린이집            가정                 19          6.0
# 14  서울특별시  서대문구        나빛어린이집            가정                 20          6.0
# 15  서울특별시  서대문구        다솜어린이집           국공립                 19          6.0
# 16  서울특별시  서대문구        단비어린이집            가정                 19          6.0
# 17  서울특별시  서대문구        대신어린이집         법인·단체                 52         11.0
# 18  서울특별시  서대문구       독립문어린이집            민간                116         20.0
# 19  서울특별시  서대문구       돈의문어린이집           국공립                 30          8.0
# 20  서울특별시  서대문구        동방어린이집           국공립                 76         12.0
# 21  서울특별시  서대문구   동우어린이나라어린이집            민간                128         20.0
# 22  서울특별시  서대문구       두란노어린이집            민간                 58         11.0
# 23  서울특별시  서대문구      두산꽃님어린이집            가정                 19          6.0
# 24  서울특별시  서대문구        또래어린이집            가정                 12          6.0
# 25  서울특별시  서대문구       또오기어린이집            가정                 14          6.0
# 26  서울특별시  서대문구        뜨란어린이집            민간                 34          8.0
# 27  서울특별시  서대문구     리틀삐아제어린이집            가정                 16          5.0
# 28  서울특별시  서대문구        마미어린이집            민간                 35         11.0
# 29  서울특별시  서대문구       맑은숲어린이집           국공립                 46         12.0
# 30  서울특별시  서대문구        명랑어린이집           국공립                 82         14.0
# 31  서울특별시  서대문구        명성어린이집            민간                 27          7.0
# 32  서울특별시  서대문구     명지대학교어린이집            민간                 93         13.0
# 33  서울특별시  서대문구       무지개어린이집            민간                 24          7.0
# 34  서울특별시  서대문구        미가어린이집            가정                 19          6.0
# 35  서울특별시  서대문구        미키어린이집            민간                 47          7.0
# 36  서울특별시  서대문구        배화어린이집            민간                 49         13.0
# 37  서울특별시  서대문구        백합어린이집            가정                 20          7.0
# 38  서울특별시  서대문구        벽산어린이집            가정                 19          6.0
# 39  서울특별시  서대문구        별빛어린이집           국공립                 30          9.0
# 40  서울특별시  서대문구       별초롱어린이집            가정                 15          5.0
# 41  서울특별시  서대문구        보은어린이집         법인·단체                 74         10.0
# 42  서울특별시  서대문구     북성엘리트어린이집            민간                 48         11.0
# 43  서울특별시  서대문구  북아현방과후교실어린이집           국공립                 40          6.0
# 44  서울특별시  서대문구       북아현어린이집           국공립                 79         14.0
# 45  서울특별시  서대문구        사랑어린이집            가정                 19          6.0
# 46  서울특별시  서대문구        산들어린이집           국공립                 37          8.0
# 47  서울특별시  서대문구       산마루어린이집           국공립                 62         11.0
# 48  서울특별시  서대문구      삼성영재어린이집            가정                 19          6.0
# 49  서울특별시  서대문구      삼성이화어린이집            민간                 32          9.0
#
#     nursing_room_num  playground_num  CCTV_num is_commuting_vehicle
# 0                5.0             1.0       7.0                    N
# 1                5.0             2.0      10.0                    N
# 2                6.0             1.0      32.0                    N
# 3                3.0             0.0       4.0                    N
# 4                7.0             2.0      10.0                    N
# 5                3.0             0.0       4.0                    N
# 6                5.0             2.0       6.0                    N
# 7                4.0             0.0       5.0                    N
# 8                3.0             0.0       4.0                    N
# 9                4.0             0.0       7.0                    N
# 10               3.0             0.0       5.0                    N
# 11               4.0             1.0       7.0                    N
# 12               3.0             0.0       3.0                    N
# 13               3.0             0.0       4.0                    N
# 14               3.0             0.0       4.0                    N
# 15               3.0             0.0       4.0                    N
# 16               4.0             0.0       4.0                    N
# 17               5.0             1.0       5.0                    Y
# 18               6.0             1.0      14.0                    Y
# 19               6.0             0.0      10.0                    N
# 20              10.0             1.0      14.0                    N
# 21               7.0             1.0      10.0                    Y
# 22               6.0             0.0      10.0                    Y
# 23               4.0             0.0       5.0                    Y
# 24               3.0             0.0       5.0                    N
# 25               2.0             0.0       4.0                    N
# 26               4.0             0.0       6.0                    N
# 27               3.0             0.0       4.0                    N
# 28               4.0             2.0       4.0                    Y
# 29               4.0             1.0       8.0                    N
# 30               8.0             1.0      13.0                    N
# 31               5.0             0.0       8.0                    N
# 32               6.0             2.0      11.0                    N
# 33               3.0             0.0       4.0                    Y
# 34               4.0             0.0       4.0                    N
# 35               5.0             0.0      11.0                    Y
# 36               8.0             0.0       8.0                    Y
# 37               3.0             0.0       5.0                    N
# 38               4.0             0.0       0.0                    N
# 39               3.0             0.0       7.0                    N
# 40               2.0             4.0       4.0                    N
# 41               6.0             0.0       7.0                    N
# 42               6.0             0.0       6.0                    Y
# 43               2.0             1.0       4.0                    N
# 44               5.0             2.0       8.0                    N
# 45               3.0             0.0       4.0                    N
# 46               4.0             0.0       6.0                    N
# 47               0.0             1.0       4.0                    N
# 48               3.0             0.0       4.0                    N
# 49               5.0             0.0       5.0                    N
#        city    gu  day_care_name day_care_type  day_care_baby_num  \
# 1567  부산광역시   영도구       까꿍영재어린이집            가정                 19
# 1568  부산광역시   영도구       대원숲속어린이집            가정                 20
# 1569  부산광역시   영도구    롯데낙천대애플어린이집            가정                 17
# 1570  부산광역시   영도구         미주어린이집            가정                 14
# 1571  부산광역시   영도구       보혜영재어린이집            가정                 18
# 1572  부산광역시   영도구        아이존어린이집            가정                 20
# 1573  부산광역시   영도구      일신큰사랑어린이집            가정                 18
# 1574  부산광역시   영도구        참사랑어린이집            가정                 13
# 1575  부산광역시   영도구         토토어린이집            가정                 20
# 1576  부산광역시   영도구         튼튼어린이집            가정                 19
# 1577  부산광역시   영도구         다솜어린이집           국공립                109
# 1578  부산광역시   영도구         동삼어린이집           국공립                 36
# 1579  부산광역시   영도구         동심어린이집           국공립                 59
# 1580  부산광역시   영도구         봉래어린이집           국공립                 74
# 1581  부산광역시   영도구         삼진어린이집           국공립                 96
# 1582  부산광역시   영도구       상리자연어린이집           국공립                 87
# 1583  부산광역시   영도구         신선어린이집           국공립                 72
# 1584  부산광역시   영도구     영도초등학교어린이집           국공립                 47
# 1585  부산광역시   영도구         영선어린이집           국공립                 68
# 1586  부산광역시   영도구         와치어린이집           국공립                 89
# 1587  부산광역시   영도구         절영어린이집           국공립                 93
# 1588  부산광역시   영도구         청동어린이집           국공립                 58
# 1589  부산광역시   영도구        그린힐어린이집            민간                 67
# 1590  부산광역시   영도구        꿈동산어린이집            민간                 83
# 1591  부산광역시   영도구         녹야어린이집            민간                 45
# 1592  부산광역시   영도구       동삼중앙어린이집            민간                 85
# 1593  부산광역시   영도구       롯데아람어린이집            민간                 26
# 1594  부산광역시   영도구       몬테소리어린이집            민간                 60
# 1595  부산광역시   영도구         반도어린이집            민간                 32
# 1596  부산광역시   영도구     벧엘영아전담어린이집            민간                 51
# 1597  부산광역시   영도구        브래뉴어린이집            민간                 27
# 1598  부산광역시   영도구         새싹어린이집            민간                 60
# 1599  부산광역시   영도구        솜사탕어린이집            민간                 49
# 1600  부산광역시   영도구        아이뜰어린이집            민간                 39
# 1601  부산광역시   영도구       영도중앙어린이집            민간                 87
# 1602  부산광역시   영도구         영지어린이집            민간                128
# 1603  부산광역시   영도구         초롱어린이집            민간                 24
# 1604  부산광역시   영도구    큰나무영아전담어린이집            민간                 35
# 1605  부산광역시   영도구        해돋이어린이집            민간                 85
# 1606  부산광역시   영도구    고신대학교부설어린이집         법인·단체                 78
# 1607  부산광역시   영도구       동삼사랑어린이집         법인·단체                 39
# 1608  부산광역시   영도구         산돌어린이집         법인·단체                 49
# 1609  부산광역시   영도구         성은어린이집         법인·단체                 71
# 1610  부산광역시   영도구         원광어린이집         법인·단체                 53
# 1611  부산광역시   영도구         은혜어린이집         법인·단체                 84
# 1612  부산광역시   영도구         효성어린이집         법인·단체                 79
# 1613  부산광역시   영도구         지성어린이집        사회복지법인                 98
# 1614  부산광역시   영도구  남해지방해양경찰청어린이집            직장                 70
# 1615  부산광역시   영도구       한국해양어린이집            직장                 78
# 1616  부산광역시  부산진구     BNK전포동어린이집            직장                 49
#
#       teacher_num  nursing_room_num  playground_num  CCTV_num  \
# 1567          6.0               NaN             NaN       NaN
# 1568          6.0               NaN             NaN       NaN
# 1569          5.0               NaN             NaN       NaN
# 1570          4.0               NaN             NaN       NaN
# 1571          5.0               NaN             NaN       NaN
# 1572          5.0               NaN             NaN       NaN
# 1573          7.0               NaN             NaN       NaN
# 1574          6.0               NaN             NaN       NaN
# 1575          5.0               NaN             NaN       NaN
# 1576          6.0               NaN             NaN       NaN
# 1577         15.0               NaN             NaN       NaN
# 1578          8.0               NaN             NaN       NaN
# 1579          9.0               NaN             NaN       NaN
# 1580         13.0               NaN             NaN       NaN
# 1581         17.0               NaN             NaN       NaN
# 1582         12.0               NaN             NaN       NaN
# 1583         14.0               NaN             NaN       NaN
# 1584         12.0               NaN             NaN       NaN
# 1585         15.0               NaN             NaN       NaN
# 1586         14.0               NaN             NaN       NaN
# 1587         15.0               NaN             NaN       NaN
# 1588          7.0               NaN             NaN       NaN
# 1589         11.0               NaN             NaN       NaN
# 1590         11.0               NaN             NaN       NaN
# 1591         12.0               NaN             NaN       NaN
# 1592         18.0               NaN             NaN       NaN
# 1593          2.0               NaN             NaN       NaN
# 1594          9.0               NaN             NaN       NaN
# 1595          5.0               NaN             NaN       NaN
# 1596         12.0               NaN             NaN       NaN
# 1597          5.0               NaN             NaN       NaN
# 1598         11.0               NaN             NaN       NaN
# 1599          4.0               NaN             NaN       NaN
# 1600          8.0               NaN             NaN       NaN
# 1601         14.0               NaN             NaN       NaN
# 1602         12.0               NaN             NaN       NaN
# 1603          3.0               NaN             NaN       NaN
# 1604         11.0               NaN             NaN       NaN
# 1605         14.0               NaN             NaN       NaN
# 1606         12.0               NaN             NaN       NaN
# 1607          9.0               NaN             NaN       NaN
# 1608          8.0               NaN             NaN       NaN
# 1609         12.0               NaN             NaN       NaN
# 1610         10.0               NaN             NaN       NaN
# 1611         10.0               NaN             NaN       NaN
# 1612         13.0               NaN             NaN       NaN
# 1613         20.0               NaN             NaN       NaN
# 1614         15.0               NaN             NaN       NaN
# 1615          8.0               NaN             NaN       NaN
# 1616         13.0               4.0             NaN       9.0
#
#      is_commuting_vehicle
# 1567                    Y
# 1568                    Y
# 1569                    Y
# 1570                    Y
# 1571                    Y
# 1572                    Y
# 1573                    Y
# 1574                    Y
# 1575                    Y
# 1576                    N
# 1577                    Y
# 1578                    Y
# 1579                    Y
# 1580                    Y
# 1581                    Y
# 1582                    Y
# 1583                    Y
# 1584                    Y
# 1585                    Y
# 1586                    Y
# 1587                    Y
# 1588                    Y
# 1589                    Y
# 1590                    Y
# 1591                    Y
# 1592                    Y
# 1593                    N
# 1594                    Y
# 1595                    Y
# 1596                    Y
# 1597                    N
# 1598                    Y
# 1599                    Y
# 1600                    Y
# 1601                    Y
# 1602                    Y
# 1603                    N
# 1604                    Y
# 1605                    Y
# 1606                    Y
# 1607                    Y
# 1608                    Y
# 1609                    Y
# 1610                    Y
# 1611                    Y
# 1612                    Y
# 1613                    Y
# 1614                    N
# 1615                    N
# 1616                    N

# %%
# seoul_data와 busan_data를 합쳐서 최종 'day_care_center.csv' 파일을 생성합니다
file_path = "/content/sample_data/Apartment_Price/day_care_center_final.csv"
day_care_center_df.to_csv(file_path, index=False)  # df_day_care가 파일을 불러올 때 사용한 변수라고 가정
